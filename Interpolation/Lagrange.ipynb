# %% [markdown]
# # Interpolação via método de Lagrange
#
# Se trata de um método que utiliza os polinômios de lagrange
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Esses polinômios são tais que:
#
# $\sum_{k=0}^{N} y_{k} \cdot L_{k}(x)$
#
# onde
#
# $L_{k}(x) = \frac{\prod_{j=0, j \ne k}^{N} x - x_{j}}{\prod_{j=0, j \ne k}^{N} x_{k} - x_{j}}$
